# %%
import pandas as pd

# %%
df=pd.read_csv('/content/employee_attrition_data.csv')
df.head()
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Job_Title              1000 non-null   object
#  5   Years_at_Company       1000 non-null   int64
#  6   Satisfaction_Level     1000 non-null   float64
#  7   Average_Monthly_Hours  1000 non-null   int64
#  8   Promotion_Last_5Years  1000 non-null   int64
#  9   Salary                 1000 non-null   int64
#  10  Attrition              1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
df.describe()
# Out:
#        Employee_ID          Age  Years_at_Company  Satisfaction_Level  \
# count  1000.000000  1000.000000       1000.000000         1000.000000
# mean    499.500000    42.205000          5.605000            0.505995
# std     288.819436    10.016452          2.822223            0.289797
# min       0.000000    25.000000          1.000000            0.001376
# 25%     249.750000    33.000000          3.000000            0.258866
# 50%     499.500000    43.000000          6.000000            0.505675
# 75%     749.250000    51.000000          8.000000            0.761135
# max     999.000000    59.000000         10.000000            0.999979
#
#        Average_Monthly_Hours  Promotion_Last_5Years        Salary    Attrition
# count            1000.000000            1000.000000   1000.000000  1000.000000
# mean              199.493000               0.486000  64624.980000     0.495000
# std                29.631908               0.500054  20262.984333     0.500225
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID              0
# Age                      0
# Gender                   0
# Department               0
# Job_Title                0
# Years_at_Company         0
# Satisfaction_Level       0
# Average_Monthly_Hours    0
# Promotion_Last_5Years    0
# Salary                   0
# Attrition                0
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_encoded = df.copy()

categorical_columns = ['Gender', 'Department', 'Job_Title', 'Salary']
df_encoded[categorical_columns] = df_encoded[categorical_columns].astype('category').apply(lambda x: x.cat.codes)

correlation_matrix = df_encoded.corr()

plt.figure(figsize=(10, 8))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title('Correlation Heatmap of Employee Data')

plt.show()

# %%
df_encoded
# Out:
#      Employee_ID  Age  Gender  Department  Job_Title  Years_at_Company  \
# 0              0   27       1           3          4                 9
# 1              1   53       0           4          2                10
# 2              2   59       0           3          1                 8
# 3              3   42       0           0          4                 1
# 4              4   44       0           4          2                10
# ..           ...  ...     ...         ...        ...               ...
# 995          995   39       0           2          3                 3
# 996          996   50       1           0          4                 1
# 997          997   52       1           0          1                 3
# 998          998   37       0           2          3                 2
# 999          999   59       1           4          3                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %%
df.drop('Employee_ID',axis=1,inplace=True)
df
# Out:
#      Age  Gender   Department      Job_Title  Years_at_Company  \
# 0     27    Male    Marketing        Manager                 9
# 1     53  Female        Sales       Engineer                10
# 2     59  Female    Marketing        Analyst                 8
# 3     42  Female  Engineering        Manager                 1
# 4     44  Female        Sales       Engineer                10
# ..   ...     ...          ...            ...               ...
# 995   39  Female           HR  HR Specialist                 3
# 996   50    Male  Engineering        Manager                 1
# 997   52    Male  Engineering        Analyst                 3
# 998   37  Female           HR  HR Specialist                 2
# 999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0              0.586251                    151                      0   60132
# ...

# %%
sns.countplot(x='Attrition', data=df,palette='pastel',hue='Attrition')
plt.title('Distribution of Attrition')
plt.show()

# %%
cat=df.select_dtypes(include='object').columns
for i in cat:
  sns.countplot(x=i, data=df,palette='dark')
  plt.title('Distribution of'+i)
  plt.show()
# Out:
# <ipython-input-53-dbc87dac6925>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=i, data=df,palette='dark')
# <ipython-input-53-dbc87dac6925>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=i, data=df,palette='dark')
# <ipython-input-53-dbc87dac6925>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=i, data=df,palette='dark')

# %%
sns.barplot(x='Department', y='Promotion_Last_5Years', data=df, palette='viridis', estimator=sum)
plt.title('Total Promotions by Department')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-54-4f864f3a1049>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Department', y='Promotion_Last_5Years', data=df, palette='viridis', estimator=sum)

# %%
sns.barplot(x='Department', y='Salary', data=df, palette='viridis', estimator=sum)
plt.title('Highest Salary in each Department')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-55-664f9ca068d4>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Department', y='Salary', data=df, palette='viridis', estimator=sum)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Department', hue='Attrition', data=df)
plt.title('Department vs. Attrition')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Gender', hue='Attrition', data=df)
plt.title('Gender vs. Attrition')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

x=df.drop('Attrition',axis=1)
y=df['Attrition']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.5,stratify=y,random_state=42)


model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(x, y)


feature_importances = pd.Series(model.feature_importances_, index=x.columns)

threshold = 0.01
selected_features = feature_importances[feature_importances > threshold].index


x_selected = x[selected_features]

print("Selected Features:", list(selected_features))
# Out:
# Selected Features: ['Age', 'Gender', 'Department', 'Job_Title', 'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours', 'Promotion_Last_5Years', 'Salary']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in x_selected.columns:
  if x_selected[i].dtype=='object':
    x_selected[i]=le.fit_transform(x_selected[i])
x_selected
# Out:
#      Age  Gender  Department  Job_Title  Years_at_Company  Satisfaction_Level  \
# 0     27       1           3          4                 9            0.586251
# 1     53       0           4          2                10            0.261161
# 2     59       0           3          1                 8            0.304382
# 3     42       0           0          4                 1            0.480779
# 4     44       0           4          2                10            0.636244
# ..   ...     ...         ...        ...               ...                 ...
# 995   39       0           2          3                 3            0.377435
# 996   50       1           0          4                 1            0.431152
# 997   52       1           0          1                 3            0.647102
# 998   37       0           2          3                 2            0.304813
# 999   59       1           4          3                 1            0.940510
#
# ...

# %%
#x=df.drop('Attrition',axis=1)
#y=df['Attrition']
x=x_selected
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.5,stratify=y,random_state=42)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (500, 9) (500,)
# (500, 9) (500,)

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

# K-Nearest Neighbors (KNN) Classifier
from sklearn.neighbors import KNeighborsClassifier

# AdaBoost Classifier
from sklearn.ensemble import AdaBoostClassifier

# XGBoost Classifier
from xgboost import XGBClassifier

# Support Vector Classifier (SVC)
from sklearn.svm import SVC

# Logistic Regression
from sklearn.linear_model import LogisticRegression

# Naive Bayes Classifier
from sklearn.naive_bayes import GaussianNB

# Polynomial Classifier (Pipeline for Polynomial Features + Logistic Regression)
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import classification_report
models={
    'DecisionTreeClassifier':DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=2,min_samples_leaf=1,max_features=None),
    'RandomForestClassifier':RandomForestClassifier(n_estimators=200,criterion='gini',max_depth=None, min_samples_split=2,min_samples_leaf=1,max_features='sqrt',random_state=42),
    'GradientBoostingClassifier':GradientBoostingClassifier(n_estimators=200,learning_rate=0.1,max_depth=3,min_samples_split=2,min_samples_leaf=1,subsample=1.0,random_state=42),
    'KNeighborsClassifier':KNeighborsClassifier(n_neighbors=5,weights='uniform',algorithm='auto',leaf_size=30,metric='minkowski',p=2),
    'AdaBoostClassifier':AdaBoostClassifier(n_estimators=200,learning_rate=0.5,estimator=DecisionTreeClassifier(max_depth=1),random_state=42),
    'XGBClassifier':XGBClassifier(n_estimators=200,learning_rate=0.1,max_depth=6,subsample=0.8,colsample_bytree=0.8,gamma=0,reg_alpha=0,reg_lambda=1,random_state=42),
    'SVC':SVC(C=1.0,kernel='rbf',gamma='scale',probability=True),
    'LogisticRegression':LogisticRegression(penalty='l2',C=1.0,solver='lbfgs',max_iter=300,random_state=42),
    'GaussianNB':GaussianNB(var_smoothing=1e-9)
}
for model_name,model in models.items():
  model.fit(x_train,y_train)
  pred=model.predict(x_test)
  print('Result of:'+''+model_name)
  print(classification_report(y_test,pred))
  print('TrainingScore:',model.score(x_train,y_train))
  print('TestScore:',model.score(x_test,y_test))
# Out:
# Result of:DecisionTreeClassifier
#               precision    recall  f1-score   support
#
#            0       0.48      0.49      0.49       253
#            1       0.47      0.45      0.46       247
#
#     accuracy                           0.47       500
#    macro avg       0.47      0.47      0.47       500
# weighted avg       0.47      0.47      0.47       500
#
# TrainingScore: 1.0
# TestScore: 0.474
# Result of:RandomForestClassifier
#               precision    recall  f1-score   support
#
#            0       0.51      0.52      0.52       253
#            1       0.50      0.49      0.50       247
#
#     accuracy                           0.51       500
#    macro avg       0.51      0.51      0.51       500
# weighted avg       0.51      0.51      0.51       500
#
# TrainingScore: 1.0
# TestScore: 0.508
# Result of:GradientBoostingClassifier
#               precision    recall  f1-score   support
#
#            0       0.51      0.49      0.50       253
# ...
